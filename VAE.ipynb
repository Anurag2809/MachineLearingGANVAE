# %%
# prerequisites
# !pip install q keras==2.4.3

import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.layers import Input, Dense, Lambda
from keras.models import Model
from keras import backend as K
from keras import objectives
from scipy.stats import norm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: q in /usr/local/lib/python3.9/dist-packages (2.7)
# Requirement already satisfied: keras==2.4.3 in /usr/local/lib/python3.9/dist-packages (2.4.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.9/dist-packages (from keras==2.4.3) (3.8.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.9/dist-packages (from keras==2.4.3) (1.10.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from keras==2.4.3) (6.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.9/dist-packages (from keras==2.4.3) (1.22.4)

# %%
# data load
(x_tr, y_tr), (x_te, y_te) = mnist.load_data()
x_tr, x_te = x_tr.astype('float32')/255., x_te.astype('float32')/255.
x_tr, x_te = x_tr.reshape(x_tr.shape[0], -1), x_te.reshape(x_te.shape[0], -1)
print(x_tr.shape, x_te.shape)

# network parameters
batch_size, n_epoch = 100, 100
n_hidden, z_dim = 256, 2
# Out:
# (60000, 784) (10000, 784)

# %%
# encoder
x = Input(shape=(x_tr.shape[1:]))
x_encoded = Dense(n_hidden, activation='relu')(x)
x_encoded = Dense(n_hidden//2, activation='relu')(x_encoded)

mu = Dense(z_dim)(x_encoded)
log_var = Dense(z_dim)(x_encoded)

# %%
# sampling function
def sampling(args):
    mu, log_var = args
    eps = K.random_normal(shape=(batch_size, z_dim), mean=0., stddev=1.0)
    return mu + K.exp(log_var) * eps

z = Lambda(sampling, output_shape=(z_dim,))([mu, log_var])

# %%
# decoder
z_decoder1 = Dense(n_hidden//2, activation='relu')
z_decoder2 = Dense(n_hidden, activation='relu')
y_decoder = Dense(x_tr.shape[1], activation='sigmoid')

z_decoded = z_decoder1(z)
z_decoded = z_decoder2(z_decoded)
y = y_decoder(z_decoded)

# %%
# loss
reconstruction_loss = objectives.binary_crossentropy(x, y) * x_tr.shape[1]
kl_loss = 0.5 * K.sum(K.square(mu) + K.exp(log_var) - log_var - 1, axis = -1)
vae_loss = reconstruction_loss + kl_loss

# build model
vae = Model(x, y)
vae.add_loss(vae_loss)
vae.compile(optimizer='rmsprop')
vae.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 784)]        0           []
#
#  dense_7 (Dense)                (None, 256)          200960      ['input_2[0][0]']
#
#  dense_8 (Dense)                (None, 128)          32896       ['dense_7[0][0]']
#
#  dense_9 (Dense)                (None, 2)            258         ['dense_8[0][0]']
#
#  dense_10 (Dense)               (None, 2)            258         ['dense_8[0][0]']
#
#  lambda_1 (Lambda)              (100, 2)             0           ['dense_9[0][0]',
#                                                                   'dense_10[0][0]']
#
#  dense_11 (Dense)               (100, 128)           384         ['lambda_1[0][0]']
#
#  dense_12 (Dense)               (100, 256)           33024       ['dense_11[0][0]']
#
#  dense_13 (Dense)               (100, 784)           201488      ['dense_12[0][0]']
#
#  tf.math.square (TFOpLambda)    (None, 2)            0           ['dense_9[0][0]']
#
#  tf.math.exp (TFOpLambda)       (None, 2)            0           ['dense_10[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 2)           0           ['tf.math.square[0][0]',
#  da)                                                              'tf.math.exp[0][0]']
#
#  tf.cast (TFOpLambda)           (None, 784)          0           ['input_2[0][0]']
#
#  tf.convert_to_tensor (TFOpLamb  (100, 784)          0           ['dense_13[0][0]']
#  da)
#
#  tf.math.subtract (TFOpLambda)  (None, 2)            0           ['tf.__operators__.add[0][0]',
#                                                                   'dense_10[0][0]']
#
#  tf.keras.backend.binary_crosse  (100, 784)          0           ['tf.cast[0][0]',
#  ntropy (TFOpLambda)                                              'tf.convert_to_tensor[0][0]']
#
#  tf.math.subtract_1 (TFOpLambda  (None, 2)           0           ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.reduce_mean (TFOpLambd  (100,)              0           ['tf.keras.backend.binary_crossen
#  a)                                                              tropy[0][0]']
#
#  tf.math.reduce_sum (TFOpLambda  (None,)             0           ['tf.math.subtract_1[0][0]']
#  )
#
#  tf.math.multiply (TFOpLambda)  (100,)               0           ['tf.math.reduce_mean[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None,)             0           ['tf.math.reduce_sum[0][0]']
#  )
#
#  tf.__operators__.add_1 (TFOpLa  (100,)              0           ['tf.math.multiply[0][0]',
#  mbda)                                                            'tf.math.multiply_1[0][0]']
#
#  add_loss (AddLoss)             (100,)               0           ['tf.__operators__.add_1[0][0]']
#
# ==================================================================================================
# Total params: 469,268
# Trainable params: 469,268
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# train
vae.fit(x_tr,
       shuffle=True,
       epochs=n_epoch,
       batch_size=batch_size,
       validation_data=(x_te, None), verbose=1)
# Out:
# Epoch 1/100
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5c76bb0c10> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x7f5c76bb0c10>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: lineno is out of bounds
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7f5c76bb0c10> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_train_function.<locals>.train_function at 0x7f5c76bb0c10>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: lineno is out of bounds
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 599/600 [============================>.] - ETA: 0s - loss: 183.7707
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f5c74396310> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_test_function.<locals>.test_function at 0x7f5c74396310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: lineno is out of bounds
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7f5c74396310> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_test_function.<locals>.test_function at 0x7f5c74396310>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: lineno is out of bounds
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 600/600 [==============================] - 16s 25ms/step - loss: 183.7473 - val_loss: 166.9711
# Epoch 2/100
# 600/600 [==============================] - 13s 22ms/step - loss: 161.6111 - val_loss: 157.4408
# Epoch 3/100
# 600/600 [==============================] - 10s 17ms/step - loss: 154.8246 - val_loss: 153.2698
# Epoch 4/100
# 600/600 [==============================] - 10s 16ms/step - loss: 151.3640 - val_loss: 150.2069
# Epoch 5/100
# 600/600 [==============================] - 8s 14ms/step - loss: 148.9056 - val_loss: 148.0184
# Epoch 6/100
# 600/600 [==============================] - 9s 16ms/step - loss: 146.9772 - val_loss: 146.2745
# Epoch 7/100
# 600/600 [==============================] - 9s 16ms/step - loss: 145.4750 - val_loss: 144.8370
# Epoch 8/100
# 600/600 [==============================] - 9s 14ms/step - loss: 144.3183 - val_loss: 144.2532
# Epoch 9/100
# 600/600 [==============================] - 9s 15ms/step - loss: 143.3950 - val_loss: 143.3055
# Epoch 10/100
# 600/600 [==============================] - 9s 16ms/step - loss: 142.5831 - val_loss: 142.7494
# Epoch 11/100
# 600/600 [==============================] - 12s 19ms/step - loss: 141.9526 - val_loss: 142.0936
# Epoch 12/100
# 600/600 [==============================] - 10s 16ms/step - loss: 141.3190 - val_loss: 141.7052
# Epoch 13/100
# 600/600 [==============================] - 10s 16ms/step - loss: 140.8999 - val_loss: 141.1123
# Epoch 14/100
# 600/600 [==============================] - 10s 16ms/step - loss: 140.4558 - val_loss: 141.0556
# Epoch 15/100
# 600/600 [==============================] - 8s 14ms/step - loss: 139.9532 - val_loss: 140.8219
# Epoch 16/100
# 600/600 [==============================] - 10s 16ms/step - loss: 139.6177 - val_loss: 140.8006
# Epoch 17/100
# 600/600 [==============================] - 9s 16ms/step - loss: 139.2082 - val_loss: 140.8414
# Epoch 18/100
# 600/600 [==============================] - 9s 14ms/step - loss: 138.8805 - val_loss: 139.7785
# Epoch 19/100
# 600/600 [==============================] - 9s 16ms/step - loss: 138.6300 - val_loss: 139.7480
# Epoch 20/100
# 600/600 [==============================] - 10s 16ms/step - loss: 138.3850 - val_loss: 139.1799
# Epoch 21/100
# 600/600 [==============================] - 9s 15ms/step - loss: 138.1924 - val_loss: 139.1227
# Epoch 22/100
# 600/600 [==============================] - 9s 15ms/step - loss: 137.9126 - val_loss: 139.5729
# Epoch 23/100
# 600/600 [==============================] - 10s 16ms/step - loss: 137.7283 - val_loss: 138.8466
# Epoch 24/100
# 600/600 [==============================] - 10s 16ms/step - loss: 137.4716 - val_loss: 139.1571
# Epoch 25/100
# 600/600 [==============================] - 8s 14ms/step - loss: 137.4239 - val_loss: 138.7462
# Epoch 26/100
# 600/600 [==============================] - 10s 16ms/step - loss: 137.1912 - val_loss: 138.2066
# Epoch 27/100
# 600/600 [==============================] - 10s 16ms/step - loss: 137.0017 - val_loss: 138.5915
# Epoch 28/100
# 600/600 [==============================] - 8s 14ms/step - loss: 136.8359 - val_loss: 138.4192
# Epoch 29/100
# 600/600 [==============================] - 10s 16ms/step - loss: 136.7363 - val_loss: 138.3426
# Epoch 30/100
# 600/600 [==============================] - 10s 16ms/step - loss: 136.5388 - val_loss: 138.2880
# Epoch 31/100
# 600/600 [==============================] - 9s 15ms/step - loss: 136.4772 - val_loss: 138.6160
# Epoch 32/100
# 600/600 [==============================] - 9s 15ms/step - loss: 136.2825 - val_loss: 137.9790
# Epoch 33/100
# 600/600 [==============================] - 10s 16ms/step - loss: 136.1945 - val_loss: 138.0654
# Epoch 34/100
# 600/600 [==============================] - 10s 16ms/step - loss: 136.1067 - val_loss: 137.6796
# Epoch 35/100
# 600/600 [==============================] - 9s 15ms/step - loss: 135.8688 - val_loss: 138.0976
# Epoch 36/100
# 600/600 [==============================] - 10s 16ms/step - loss: 135.6938 - val_loss: 137.5166
# Epoch 37/100
# 600/600 [==============================] - 10s 16ms/step - loss: 135.5647 - val_loss: 138.0588
# Epoch 38/100
# 600/600 [==============================] - 10s 16ms/step - loss: 135.4546 - val_loss: 137.6154
# Epoch 39/100
# 600/600 [==============================] - 9s 15ms/step - loss: 135.4167 - val_loss: 138.0400
# Epoch 40/100
# 600/600 [==============================] - 10s 16ms/step - loss: 135.3352 - val_loss: 138.0773
# Epoch 41/100
# 600/600 [==============================] - 10s 16ms/step - loss: 135.1364 - val_loss: 137.1108
# Epoch 42/100
# 600/600 [==============================] - 8s 14ms/step - loss: 135.0365 - val_loss: 136.9042
# Epoch 43/100
# 600/600 [==============================] - 10s 16ms/step - loss: 134.8919 - val_loss: 137.0894
# Epoch 44/100
# 600/600 [==============================] - 10s 16ms/step - loss: 134.8511 - val_loss: 137.2299
# Epoch 45/100
# 600/600 [==============================] - 9s 15ms/step - loss: 134.7937 - val_loss: 137.7316
# Epoch 46/100
# 600/600 [==============================] - 9s 15ms/step - loss: 134.7074 - val_loss: 137.5117
# Epoch 47/100
# 600/600 [==============================] - 10s 16ms/step - loss: 134.6024 - val_loss: 137.3035
# Epoch 48/100
# 600/600 [==============================] - 9s 16ms/step - loss: 134.5410 - val_loss: 137.2891
# Epoch 49/100
# 600/600 [==============================] - 9s 14ms/step - loss: 134.5093 - val_loss: 137.0427
# Epoch 50/100
# 600/600 [==============================] - 10s 16ms/step - loss: 134.3446 - val_loss: 137.0308
# Epoch 51/100
# 600/600 [==============================] - 10s 16ms/step - loss: 134.3163 - val_loss: 137.2086
# Epoch 52/100
# 600/600 [==============================] - 9s 14ms/step - loss: 134.3468 - val_loss: 136.6563
# Epoch 53/100
# 600/600 [==============================] - 10s 16ms/step - loss: 134.1964 - val_loss: 136.7143
# Epoch 54/100
# 600/600 [==============================] - 10s 16ms/step - loss: 134.1437 - val_loss: 137.3274
# Epoch 55/100
# 600/600 [==============================] - 10s 16ms/step - loss: 134.0374 - val_loss: 136.7986
# Epoch 56/100
# 600/600 [==============================] - 8s 14ms/step - loss: 133.9122 - val_loss: 136.7803
# Epoch 57/100
# 600/600 [==============================] - 10s 16ms/step - loss: 133.9247 - val_loss: 136.8044
# Epoch 58/100
# 600/600 [==============================] - 10s 16ms/step - loss: 133.8862 - val_loss: 136.9699
# Epoch 59/100
# 600/600 [==============================] - 8s 14ms/step - loss: 133.8237 - val_loss: 136.7853
# Epoch 60/100
# 600/600 [==============================] - 10s 16ms/step - loss: 133.8195 - val_loss: 137.2804
# Epoch 61/100
# 600/600 [==============================] - 10s 16ms/step - loss: 133.7212 - val_loss: 136.8135
# Epoch 62/100
# 600/600 [==============================] - 9s 16ms/step - loss: 133.5559 - val_loss: 137.0204
# Epoch 63/100
# 600/600 [==============================] - 9s 15ms/step - loss: 133.6145 - val_loss: 137.0297
# Epoch 64/100
# 600/600 [==============================] - 10s 16ms/step - loss: 133.5531 - val_loss: 136.1953
# Epoch 65/100
# 600/600 [==============================] - 10s 16ms/step - loss: 133.4466 - val_loss: 136.7261
# Epoch 66/100
# 600/600 [==============================] - 8s 14ms/step - loss: 133.5268 - val_loss: 137.1342
# Epoch 67/100
# 600/600 [==============================] - 10s 16ms/step - loss: 133.3898 - val_loss: 137.0187
# Epoch 68/100
# 600/600 [==============================] - 10s 16ms/step - loss: 133.2498 - val_loss: 136.7274
# Epoch 69/100
# 600/600 [==============================] - 9s 15ms/step - loss: 133.1907 - val_loss: 136.5152
# Epoch 70/100
# 600/600 [==============================] - 9s 15ms/step - loss: 133.1378 - val_loss: 137.0911
# Epoch 71/100
# 600/600 [==============================] - 10s 16ms/step - loss: 133.1149 - val_loss: 136.8481
# Epoch 72/100
# 600/600 [==============================] - 10s 16ms/step - loss: 133.1133 - val_loss: 136.6976
# Epoch 73/100
# 600/600 [==============================] - 9s 14ms/step - loss: 133.0707 - val_loss: 136.4667
# Epoch 74/100
# 600/600 [==============================] - 10s 17ms/step - loss: 132.9882 - val_loss: 136.8268
# Epoch 75/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.9294 - val_loss: 136.6759
# Epoch 76/100
# 600/600 [==============================] - 9s 15ms/step - loss: 132.8633 - val_loss: 137.1648
# Epoch 77/100
# 600/600 [==============================] - 9s 16ms/step - loss: 132.8709 - val_loss: 137.5526
# Epoch 78/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.8647 - val_loss: 136.4283
# Epoch 79/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.7620 - val_loss: 137.2998
# Epoch 80/100
# 600/600 [==============================] - 9s 15ms/step - loss: 132.6874 - val_loss: 136.6086
# Epoch 81/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.7007 - val_loss: 136.4613
# Epoch 82/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.5961 - val_loss: 136.2042
# Epoch 83/100
# 600/600 [==============================] - 9s 15ms/step - loss: 132.6324 - val_loss: 137.1893
# Epoch 84/100
# 600/600 [==============================] - 9s 15ms/step - loss: 132.5721 - val_loss: 136.7100
# Epoch 85/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.5219 - val_loss: 137.3192
# Epoch 86/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.4681 - val_loss: 136.4748
# Epoch 87/100
# 600/600 [==============================] - 9s 14ms/step - loss: 132.4899 - val_loss: 136.5303
# Epoch 88/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.4216 - val_loss: 136.6044
# Epoch 89/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.5159 - val_loss: 136.9223
# Epoch 90/100
# 600/600 [==============================] - 9s 15ms/step - loss: 132.3925 - val_loss: 136.3731
# Epoch 91/100
# 600/600 [==============================] - 9s 15ms/step - loss: 132.3761 - val_loss: 136.4855
# Epoch 92/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.2703 - val_loss: 136.8146
# Epoch 93/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.3277 - val_loss: 136.7635
# Epoch 94/100
# 600/600 [==============================] - 9s 14ms/step - loss: 132.2222 - val_loss: 136.6398
# Epoch 95/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.1750 - val_loss: 136.5340
# Epoch 96/100
# 600/600 [==============================] - 10s 17ms/step - loss: 132.1715 - val_loss: 136.2103
# Epoch 97/100
# 600/600 [==============================] - 9s 15ms/step - loss: 132.1873 - val_loss: 136.4479
# Epoch 98/100
# 600/600 [==============================] - 9s 15ms/step - loss: 132.1955 - val_loss: 136.4685
# Epoch 99/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.1694 - val_loss: 136.8397
# Epoch 100/100
# 600/600 [==============================] - 10s 16ms/step - loss: 132.0966 - val_loss: 136.3960

# %%
# build encoder
encoder = Model(x, mu)
encoder.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 784)]             0
#
#  dense_7 (Dense)             (None, 256)               200960
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  dense_9 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 234,114
# Trainable params: 234,114
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Plot of the digit classes in the latent space
x_te_latent = encoder.predict(x_te, batch_size=batch_size)
plt.figure(figsize=(6, 6))
plt.scatter(x_te_latent[:, 0], x_te_latent[:, 1], c=y_te)
plt.colorbar()
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5c74551940> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x7f5c74551940>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: lineno is out of bounds
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5c74551940> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x7f5c74551940>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: lineno is out of bounds
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 100/100 [==============================] - 0s 3ms/step

# %%
# build decoder
decoder_input = Input(shape=(z_dim,))
_z_decoded = z_decoder1(decoder_input)
_z_decoded = z_decoder2(_z_decoded)
_y = y_decoder(_z_decoded)
generator = Model(decoder_input, _y)
generator.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 2)]               0
#
#  dense_11 (Dense)            multiple                  384
#
#  dense_12 (Dense)            multiple                  33024
#
#  dense_13 (Dense)            multiple                  201488
#
# =================================================================
# Total params: 234,896
# Trainable params: 234,896
# Non-trainable params: 0
# _________________________________________________________________

# %%
# display a 2D manifold of the digits
n = 15 # figure with 15x15 digits
digit_size = 28
figure = np.zeros((digit_size * n, digit_size * n))

grid_x = norm.ppf(np.linspace(0.05, 0.95, n)) 
grid_y = norm.ppf(np.linspace(0.05, 0.95, n))

for i, yi in enumerate(grid_x):
    for j, xi in enumerate(grid_y):
        z_sample = np.array([[xi, yi]])
        x_decoded = generator.predict(z_sample)
        digit = x_decoded[0].reshape(digit_size, digit_size)
        figure[i * digit_size: (i + 1) * digit_size,
               j * digit_size: (j + 1) * digit_size] = digit

plt.figure(figsize=(10, 10))
plt.imshow(figure, cmap='Greys_r')
plt.show()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5c66718040> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x7f5c66718040>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: lineno is out of bounds
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7f5c66718040> and will run it as-is.
# Cause: Unable to locate the source code of <function Model.make_predict_function.<locals>.predict_function at 0x7f5c66718040>. Note that functions defined in certain environments, like the interactive Python shell, do not expose their source code. If that is the case, you should define them in a .py source file. If you are certain the code is graph-compatible, wrap the call using @tf.autograph.experimental.do_not_convert. Original error: lineno is out of bounds
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
